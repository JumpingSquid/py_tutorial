# %% [markdown]
# # Module2. Matplotlib
# 資料視覺化可以幫助我們更快且直覺的了解資料。在Python裡，有兩個主要的套件可以協助我們做資料視覺化，分別是 Matplotlib 跟 Seaborn。
# Matplotlib 具備很高的彈性，他允許使用者對圖表的各項元素做調整(包含標題、坐標軸、圖表本身等)。而Seaborn則是基於Matplotlib 的套件，它簡化了作圖的流程跟指令，
# 在視覺美感跟互動性上也優於 Matplotlib。考慮到泛用性，我們這章節會以Matplotlib為主。
# Data visualization help the user to explore the data more quickly and intuitively.
# In Python, there are two major packages, Matplotlib and Seaborn.
# Matplotlib is a more flexible package, it allows user to design a customized chart.
# Seaborn is a visualization tool built on Matplotlib, it encapsulates some of Maplotlib's functions and
#  provides a more user-friendly experience.
# In this module, we will try to use Matplotlib to produce some basic charts.

# %% [markdown]
# ![Seaborn Demo](https://github.com/JumpingSquid/py_tutorial/blob/master/image/seaborn_demo.png?raw=true)
# ![Matplotlib demo](https://github.com/JumpingSquid/py_tutorial/blob/master/image/matplotlib_demo.png?raw=true)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# we read the data (if you run this in the local environment, you can read 'titanic.csv' instead)
df = pd.read_csv("https://raw.githubusercontent.com/JumpingSquid/py_tutorial/master/titanic.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2fb98a1842f2> in <module>
# ----> 1 df = pd.read_csv("titanic.csv")
#
# NameError: name 'pd' is not defined

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Line Chart

# %%
plt.plot([1,2,3,4,5], [2,4,6,7,10])

# %% [markdown]
# ## Bar Plot

# %%
Pclass_count = df.Pclass.value_counts()
plt.bar(Pclass_count.index, Pclass_count.values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ## Histogram

# %%
plt.hist(df.Age.dropna())
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ## Box Plot

# %%
fig,axes = plt.subplots()
df.boxplot(column='Fare',by=['Pclass'],ax=axes)

# %% [markdown]
# ## Scatter Plot

# %%
plt.scatter(x=df.Age, y=df.Fare)

# %%
# We can also use color to differentiate the category
plt.scatter(x=df.Age, y=df.Fare, c= np.where(df.Sex=="female",1,0), cmap="coolwarm")
